# %%
import json
input_file=open('data.json', 'r')

#output_file=open('test.json', 'w')
json_decode=json.load(input_file)
json_decode
# Out:
# [{'status': 'succeeded',
#   'createdDateTime': '2020-05-02T13:58:50Z',
#   'lastUpdatedDateTime': '2020-05-02T13:58:59Z',
#   'analyzeResult': {'version': '2.0.0',
#    'readResults': [{'page': 1,
#      'angle': -0.6992,
#      'width': 8.2606,
#      'height': 11.3439,
#      'unit': 'inch',
#      'language': 'en',
#      'lines': [{'text': 'World Health',
#        'boundingBox': [1.5001,
#         0.3767,
#         3.0435,
#         0.3767,
#         3.0435,
#         0.64,
#         1.5001,
#         0.65],
#        'words': [{'text': 'World',
#          'boundingBox': [1.5162,
#           0.3784,
#           2.2185,
#           0.3768,
#           2.2118,
#           0.65,
#           1.5093,
#           0.65],
#          'confidence': 0.959},
#         {'text': 'Health',
#          'boundingBox': [2.2725,
#           0.3768,
#           3.0378,
#           0.3792,
#           3.0314,
#           0.6406,
#           2.2659,
#           0.65],
#          'confidence': 0.959}]},
#       {'text': 'Organization',
#        'boundingBox': [1.5201,
#         0.65,
#         3.0635,
#         0.65,
#         3.0635,
#         0.9567,
#         1.5201,
#         0.9567],
#        'words': [{'text': 'Organization',
#          'boundingBox': [1.5219,
#           0.6583,
#           3.0652,
#           0.6513,
#           3.0562,
#           0.96,
#           1.5235,
#           0.9562],
#          'confidence': 0.958}]},
#       {'text': 'Revised case report form for Confirmed Novel Coronavirus COVID-19',
#        'boundingBox': [1.2468,
#         1.3667,
#         7.5872,
#         1.3001,
#         7.5905,
#         1.5234,
#         1.2468,
#         1.5767],
#        'words': [{'text': 'Revised',
#          'boundingBox': [1.2486,
#           1.3699,
#           1.9694,
#           1.3644,
#           1.9688,
#           1.5767,
#           1.247,
#           1.5767],
#          'confidence': 0.959},
#         {'text': 'case',
#          'boundingBox': [2.0105,
#           1.3641,
#           2.3949,
#           1.3609,
#           2.395,
#           1.5767,
#           2.0101,
#           1.5767],
#          'confidence': 0.959},
#         {'text': 'report',
#          'boundingBox': [2.4361,
#           1.3606,
#           3.0402,
#           1.3553,
#           3.0412,
#           1.5767,
#           2.4363,
#           1.5767],
#          'confidence': 0.959},
#         {'text': 'form',
#          'boundingBox': [3.0814,
#           1.3549,
#           3.4795,
#           1.351,
#           3.4812,
#           1.574,
#           3.0825,
#           1.5767],
#          'confidence': 0.958},
#         {'text': 'for',
#          'boundingBox': [3.5756,
#           1.35,
#           3.8639,
#           1.3472,
#           3.8661,
#           1.5712,
#           3.5774,
#           1.5733],
#          'confidence': 0.925},
#         {'text': 'Confirmed',
#          'boundingBox': [3.9051,
#           1.3468,
#           4.8798,
#           1.3362,
#           4.8835,
#           1.5601,
#           3.9074,
#           1.5709],
#          'confidence': 0.959},
#         {'text': 'Novel',
#          'boundingBox': [4.9209,
#           1.3357,
#           5.4838,
#           1.3288,
#           5.4885,
#           1.5509,
#           4.9248,
#           1.5594],
#          'confidence': 0.909},
#         {'text': 'Coronavirus',
#          'boundingBox': [5.525,
#           1.3284,
#           6.6232,
#           1.3141,
#           6.6296,
#           1.5303,
#           5.5297,
#           1.5503],
#          'confidence': 0.957},
#         {'text': 'COVID-19',
#          'boundingBox': [6.6644,
#           1.3136,
#           7.5773,
#           1.3005,
#           7.585,
#           1.5084,
#           6.6708,
#           1.5295],
#          'confidence': 0.816}]},
#       {'text': '(report to WHO within 48 hours of case identification)',
#        'boundingBox': [1.9235,
#         1.6067,
#         6.9171,
#         1.5601,
#         6.9205,
#         1.7968,
#         1.9235,
#         1.8268],
#        'words': [{'text': '(report',
#          'boundingBox': [1.9325,
#           1.6284,
#           2.5997,
#           1.6192,
#           2.6014,
#           1.8268,
#           1.9331,
#           1.8268],
#          'confidence': 0.849},
#         {'text': 'to',
#          'boundingBox': [2.639,
#           1.6186,
#           2.8483,
#           1.6158,
#           2.8503,
#           1.8268,
#           2.6407,
#           1.8268],
#          'confidence': 0.958},
#         {'text': 'WHO',
#          'boundingBox': [2.8876,
#           1.6152,
#           3.3716,
#           1.6086,
#           3.3745,
#           1.8268,
#           2.8896,
#           1.8268],
#          'confidence': 0.957},
#         {'text': 'within',
#          'boundingBox': [3.424,
#           1.6079,
#           4.0258,
#           1.5996,
#           4.0297,
#           1.8245,
#           3.4269,
#           1.8267],
#          'confidence': 0.953},
#         {'text': '48',
#          'boundingBox': [4.0651,
#           1.5991,
#           4.2875,
#           1.596,
#           4.2918,
#           1.8233,
#           4.069,
#           1.8245],
#          'confidence': 0.958},
#         {'text': 'hours',
#          'boundingBox': [4.3267,
#           1.5955,
#           4.8762,
#           1.588,
#           4.8815,
#           1.82,
#           4.3311,
#           1.8231],
#          'confidence': 0.958},
#         {'text': 'of',
#          'boundingBox': [4.9155,
#           1.5874,
#           5.1248,
#           1.5846,
#           5.1304,
#           1.8182,
#           4.9208,
#           1.8197],
#          'confidence': 0.959},
#         {'text': 'case',
#          'boundingBox': [5.1641,
#           1.584,
#           5.5435,
#           1.5788,
#           5.5498,
#           1.8151,
#           5.1697,
#           1.8179],
#          'confidence': 0.959},
#         {'text': 'identification)',
#          'boundingBox': [5.5827,
#           1.5783,
#           6.9107,
#           1.5602,
#           6.9191,
#           1.8017,
#           5.5891,
#           1.8148],
#          'confidence': 0.93}]},
#       {'text': 'Date of reporting to national health authority: [ /_][ 81/LO][ 41/121LOL 21101',
#        'boundingBox': [0.5767,
#         2.0101,
#         6.3804,
#         1.9301,
#         6.3838,
#         2.1934,
#         0.58,
#         2.2201],
#        'words': [{'text': 'Date',
#          'boundingBox': [0.6031,
#           2.0678,
#           0.9234,
#           2.0603,
#           0.93,
#           2.2201,
#           0.6102,
#           2.2201],
#          'confidence': 0.958},
#         {'text': 'of',
#          'boundingBox': [0.9535,
#           2.0596,
#           1.0936,
#           2.0563,
#           1.0999,
#           2.2201,
#           0.96,
#           2.2201],
#          'confidence': 0.957},
#         {'text': 'reporting',
#          'boundingBox': [1.1236,
#           2.0556,
#           1.7543,
#           2.0409,
#           1.7596,
#           2.2201,
#           1.1299,
#           2.2201],
#          'confidence': 0.959},
#         {'text': 'to',
#          'boundingBox': [1.7843,
#           2.0402,
#           1.9345,
#           2.0366,
#           1.9395,
#           2.2201,
#           1.7895,
#           2.2201],
#          'confidence': 0.925},
#         {'text': 'national',
#          'boundingBox': [1.9645,
#           2.0359,
#           2.5051,
#           2.0233,
#           2.5091,
#           2.2201,
#           1.9694,
#           2.2201],
#          'confidence': 0.938},
#         {'text': 'health',
#          'boundingBox': [2.5351,
#           2.0226,
#           2.9556,
#           2.0127,
#           2.9589,
#           2.2195,
#           2.5391,
#           2.2201],
#          'confidence': 0.958},
#         {'text': 'authority:',
#          'boundingBox': [2.9856,
#           2.012,
#           3.6363,
#           1.9968,
#           3.6385,
#           2.2173,
#           2.9889,
#           2.2194],
#          'confidence': 0.949},
#         {'text': '[',
#          'boundingBox': [3.6663,
#           1.9961,
#           3.7664,
#           1.9938,
#           3.7685,
#           2.2168,
#           3.6685,
#           2.2172],
#          'confidence': 0.762},
#         {'text': '/_][',
#          'boundingBox': [3.8164,
#           1.9926,
#           4.0967,
#           1.986,
#           4.0983,
#           2.2156,
#           3.8184,
#           2.2166],
#          'confidence': 0.282},
#         {'text': '81/LO][',
#          'boundingBox': [4.1268,
#           1.9853,
#           4.7975,
#           1.9697,
#           4.7979,
#           2.2121,
#           4.1283,
#           2.2154],
#          'confidence': 0.289},
#         {'text': '41/121LOL',
#          'boundingBox': [4.8275,
#           1.969,
#           5.8285,
#           1.9456,
#           5.8274,
#           2.2053,
#           4.8279,
#           2.2119],
#          'confidence': 0.252},
#         {'text': '21101',
#          'boundingBox': [5.8586,
#           1.9449,
#           6.3741,
#           1.9328,
#           6.3721,
#           2.201,
#           5.8573,
#           2.205],
#          'confidence': 0.487}]},
#       {'text': 'Reporting country:',
#        'boundingBox': [0.6134,
#         2.4868,
#         1.7768,
#         2.4868,
#         1.7768,
#         2.6401,
#         0.6134,
#         2.6335],
#        'words': [{'text': 'Reporting',
#          'boundingBox': [0.6158,
#           2.4892,
#           1.2325,
#           2.487,
#           1.2383,
#           2.6424,
#           0.6245,
#           2.6305],
#          'confidence': 0.959},
#         {'text': 'country:',
#          'boundingBox': [1.2604,
#           2.487,
#           1.7751,
#           2.4894,
#           1.7783,
#           2.6403,
#           1.266,
#           2.6426],
#          'confidence': 0.959}]},
#       {'text': 'UK',
#        'boundingBox': [2.0335,
#         2.3968,
#         2.4068,
#         2.3934,
#         2.4035,
#         2.6101,
#         2.0401,
#         2.6168],
#        'words': [{'text': 'UK',
#          'boundingBox': [2.0524,
#           2.3965,
#           2.3971,
#           2.3934,
#           2.4001,
#           2.6118,
#           2.0554,
#           2.6165],
#          'confidence': 0.694}]},
#       {'text': 'Why tested for COVID-19:',
#        'boundingBox': [0.6567,
#         2.9101,
#         2.2668,
#         2.8868,
#         2.2668,
#         3.0501,
#         0.66,
#         3.0735],
#        'words': [{'text': 'Why',
#          'boundingBox': [0.6596,
#           2.9112,
#           0.9095,
#           2.9119,
#           0.9115,
#           3.0725,
#           0.6618,
#           3.0734],
#          'confidence': 0.958},
#         {'text': 'tested',
#          'boundingBox': [0.9414,
#           2.9119,
#           1.3243,
#           2.9098,
#           1.3259,
#           3.0688,
#           0.9434,
#           3.0722],
#          'confidence': 0.958},
#         {'text': 'for',
#          'boundingBox': [1.3562,
#           2.9095,
#           1.5476,
#           2.9069,
#           1.549,
#           3.0657,
#           1.3578,
#           3.0684],
#          'confidence': 0.947},
#         {'text': 'COVID-19:',
#          'boundingBox': [1.5795,
#           2.9065,
#           2.2653,
#           2.8895,
#           2.2661,
#           3.0506,
#           1.5809,
#           3.0653],
#          'confidence': 0.916}]},
#       {'text': 'Contact of a case alll Seeking Healthcare due to suspicion of COVID-19 Detected at point of entry Repatriation',
#        'boundingBox': [0.52,
#         3.1368,
#         8.1039,
#         3.0501,
#         8.1072,
#         3.1968,
#         0.52,
#         3.2902],
#        'words': [{'text': 'Contact',
#          'boundingBox': [0.6469,
#           3.1392,
#           1.1288,
#           3.1322,
#           1.1297,
#           3.2866,
#           0.648,
#           3.2926],
#          'confidence': 0.799},
#         {'text': 'of',
#          'boundingBox': [1.159,
#           3.1318,
#           1.2794,
#           3.13,
#           1.2802,
#           3.2847,
#           1.1598,
#           3.2862],
#          'confidence': 0.958},
#         {'text': 'a',
#          'boundingBox': [1.3096,
#           3.1296,
#           1.3999,
#           3.1283,
#           1.4006,
#           3.2832,
#           1.3103,
#           3.2843],
#          'confidence': 0.891},
#         {'text': 'case',
#          'boundingBox': [1.43,
#           3.1278,
#           1.7212,
#           3.1237,
#           1.7218,
#           3.2792,
#           1.4307,
#           3.2828],
#          'confidence': 0.944},
#         {'text': 'alll',
#          'boundingBox': [1.8819,
#           3.1216,
#           2.1128,
#           3.1184,
#           2.1131,
#           3.2742,
#           1.8823,
#           3.2771],
#          'confidence': 0.355},
#         {'text': 'Seeking',
#          'boundingBox': [2.1429,
#           3.118,
#           2.6349,
#           3.1114,
#           2.635,
#           3.2676,
#           2.1432,
#           3.2738],
#          'confidence': 0.959},
#         {'text': 'Healthcare',
#          'boundingBox': [2.665,
#           3.1109,
#           3.3377,
#           3.1024,
#           3.3375,
#           3.2586,
#           2.6651,
#           3.2672],
#          'confidence': 0.939},
#         {'text': 'due',
#          'boundingBox': [3.3678,
#           3.1021,
#           3.5987,
#           3.0991,
#           3.5984,
#           3.2553,
#           3.3676,
#           3.2582],
#          'confidence': 0.948},
#         {'text': 'to',
#          'boundingBox': [3.6289,
#           3.0988,
#           3.7694,
#           3.097,
#           3.769,
#           3.2531,
#           3.6285,
#           3.2549],
#          'confidence': 0.958},
#         {'text': 'suspicion',
#          'boundingBox': [3.7996,
#           3.0966,
#           4.3719,
#           3.09,
#           4.3712,
#           3.2453,
#           3.7991,
#           3.2527],
#          'confidence': 0.951},
#         {'text': 'of',
#          'boundingBox': [4.402,
#           3.0896,
#           4.5426,
#           3.088,
#           4.5418,
#           3.2431,
#           4.4013,
#           3.2449],
#          'confidence': 0.959},
#         {'text': 'COVID-19',
#          'boundingBox': [4.5727,
#           3.0876,
#           5.2153,
#           3.0805,
#           5.2142,
#           3.2343,
#           4.5719,
#           3.2427],
#          'confidence': 0.909},
#         {'text': 'Detected',
#          'boundingBox': [5.4964,
#           3.0774,
#           6.0587,
#           3.0715,
#           6.0572,
#           3.2233,
#           5.4952,
#           3.2307],
#          'confidence': 0.762},
#         {'text': 'at',
#          'boundingBox': [6.0888,
#           3.0712,
#           6.2093,
#           3.07,
#           6.2077,
#           3.2213,
#           6.0873,
#           3.2229],
#          'confidence': 0.906},
#         {'text': 'point',
#          'boundingBox': [6.2394,
#           3.0697,
#           6.5808,
#           3.0664,
#           6.579,
#           3.2164,
#           6.2378,
#           3.2209],
#          'confidence': 0.957},
#         {'text': 'of',
#          'boundingBox': [6.6109,
#           3.0661,
#           6.7414,
#           3.0648,
#           6.7396,
#           3.2143,
#           6.6092,
#           3.216],
#          'confidence': 0.958},
#         {'text': 'entry',
#          'boundingBox': [6.7716,
#           3.0645,
#           7.113,
#           3.0613,
#           7.111,
#           3.2093,
#           6.7697,
#           3.2139],
#          'confidence': 0.958},
#         {'text': 'Repatriation',
#          'boundingBox': [7.3539,
#           3.0591,
#           8.102,
#           3.0525,
#           8.0995,
#           3.1962,
#           7.3518,
#           3.2061],
#          'confidence': 0.57}]},
#       {'text': 'Routine respiratory disease surveillance systems (e.g. influenza) a Unknown',
#        'boundingBox': [0.5367,
#         3.3368,
#         5.2804,
#         3.2802,
#         5.2804,
#         3.4568,
#         0.5367,
#         3.5068],
#        'words': [{'text': 'Routine',
#          'boundingBox': [0.6399,
#           3.3465,
#           1.1178,
#           3.3437,
#           1.1174,
#           3.5012,
#           0.639,
#           3.5068],
#          'confidence': 0.694},
#         {'text': 'respiratory',
#          'boundingBox': [1.1497,
#           3.3435,
#           1.8189,
#           3.338,
#           1.8191,
#           3.4923,
#           1.1493,
#           3.5007],
#          'confidence': 0.948},
#         {'text': 'disease',
#          'boundingBox': [1.8507,
#           3.3377,
#           2.3074,
#           3.3327,
#           2.3082,
#           3.4867,
#           1.851,
#           3.4919],
#          'confidence': 0.958},
#         {'text': 'surveillance',
#          'boundingBox': [2.3393,
#           3.3323,
#           3.0509,
#           3.3231,
#           3.0524,
#           3.4789,
#           2.3401,
#           3.4864],
#          'confidence': 0.912},
#         {'text': 'systems',
#          'boundingBox': [3.0828,
#           3.3226,
#           3.5713,
#           3.315,
#           3.5733,
#           3.4742,
#           3.0842,
#           3.4786],
#          'confidence': 0.957},
#         {'text': '(e.g.',
#          'boundingBox': [3.6032,
#           3.3145,
#           3.8581,
#           3.3103,
#           3.8603,
#           3.4716,
#           3.6052,
#           3.4739],
#          'confidence': 0.909},
#         {'text': 'influenza)',
#          'boundingBox': [3.8899,
#           3.3098,
#           4.4953,
#           3.2983,
#           4.4981,
#           3.4667,
#           3.8922,
#           3.4713],
#          'confidence': 0.909},
#         {'text': 'a',
#          'boundingBox': [4.5271,
#           3.2977,
#           4.6227,
#           3.2958,
#           4.6257,
#           3.4659,
#           4.53,
#           3.4664],
#          'confidence': 0.252},
#         {'text': 'Unknown',
#          'boundingBox': [4.6546,
#           3.2951,
#           5.2599,
#           3.2819,
#           5.2635,
#           3.4617,
#           4.6576,
#           3.4657],
#          'confidence': 0.959}]},
#       {'text': 'If none of the above, please explain:',
#        'boundingBox': [0.7767,
#         3.5468,
#         2.9202,
#         3.5268,
#         2.9235,
#         3.6902,
#         0.7767,
#         3.7102],
#        'words': [{'text': 'If',
#          'boundingBox': [0.7778,
#           3.5533,
#           0.8343,
#           3.5527,
#           0.8357,
#           3.7093,
#           0.7792,
#           3.71],
#          'confidence': 0.386},
#         {'text': 'none',
#          'boundingBox': [0.8651,
#           3.5524,
#           1.1731,
#           3.5489,
#           1.1743,
#           3.7057,
#           0.8665,
#           3.709],
#          'confidence': 0.958},
#         {'text': 'of',
#          'boundingBox': [1.2039,
#           3.5486,
#           1.3271,
#           3.5472,
#           1.3283,
#           3.7042,
#           1.2051,
#           3.7054],
#          'confidence': 0.958},
#         {'text': 'the',
#          'boundingBox': [1.3579,
#           3.5469,
#           1.553,
#           3.5447,
#           1.5541,
#           3.7023,
#           1.3591,
#           3.704],
#          'confidence': 0.957},
#         {'text': 'above,',
#          'boundingBox': [1.5838,
#           3.5443,
#           1.9843,
#           3.5397,
#           1.9851,
#           3.6992,
#           1.5849,
#           3.7021],
#          'confidence': 0.954},
#         {'text': 'please',
#          'boundingBox': [2.0151,
#           3.5394,
#           2.4155,
#           3.5347,
#           2.4161,
#           3.697,
#           2.0159,
#           3.699],
#          'confidence': 0.959},
#         {'text': 'explain:',
#          'boundingBox': [2.4463,
#           3.5343,
#           2.9235,
#           3.5287,
#           2.9235,
#           3.6955,
#           2.4469,
#           3.6969],
#          'confidence': 0.956}]},
#       {'text': 'Section 1: Patient information',
#        'boundingBox': [0.6967,
#         3.9902,
#         2.8935,
#         3.9669,
#         2.8969,
#         4.1269,
#         0.7,
#         4.1502],
#        'words': [{'text': 'Section',
#          'boundingBox': [0.7146,
#           3.9961,
#           1.2464,
#           3.9896,
#           1.25,
#           4.1454,
#           0.7192,
#           4.1502],
#          'confidence': 0.959},
#         {'text': '1:',
#          'boundingBox': [1.2976,
#           3.989,
#           1.4203,
#           3.9874,
#           1.4236,
#           4.1435,
#           1.3011,
#           4.1448],
#          'confidence': 0.911},
#         {'text': 'Patient',
#          'boundingBox': [1.451,
#           3.9871,
#           1.9828,
#           3.9803,
#           1.9851,
#           4.138,
#           1.4542,
#           4.1432],
#          'confidence': 0.959},
#         {'text': 'information',
#          'boundingBox': [2.0134,
#           3.9799,
#           2.8827,
#           3.9686,
#           2.8834,
#           4.1317,
#           2.0157,
#           4.1378],
#          'confidence': 0.914}]},
#       {'text': 'Unique Case Identifier (used in country):',
#        'boundingBox': [0.6167,
#         4.4702,
#         3.3469,
#         4.4336,
#         3.3502,
#         4.6236,
#         0.6167,
#         4.6536],
#        'words': [{'text': 'Unique',
#          'boundingBox': [0.6246,
#           4.4845,
#           1.1077,
#           4.4894,
#           1.1065,
#           4.6468,
#           0.6233,
#           4.6536],
#          'confidence': 0.849},
#         {'text': 'Case',
#          'boundingBox': [1.1414,
#           4.4895,
#           1.4223,
#           4.4898,
#           1.4211,
#           4.642,
#           1.1402,
#           4.6463],
#          'confidence': 0.959},
#         {'text': 'Identifier',
#          'boundingBox': [1.456,
#           4.4895,
#           2.0852,
#           4.4813,
#           2.084,
#           4.6347,
#           1.4548,
#           4.6416],
#          'confidence': 0.762},
#         {'text': '(used',
#          'boundingBox': [2.1189,
#           4.4806,
#           2.467,
#           4.4712,
#           2.4659,
#           4.6321,
#           2.1177,
#           4.6344],
#          'confidence': 0.851},
#         {'text': 'in',
#          'boundingBox': [2.5007,
#           4.4702,
#           2.6467,
#           4.4652,
#           2.6456,
#           4.6313,
#           2.4996,
#           4.6318],
#          'confidence': 0.958},
#         {'text': 'country):',
#          'boundingBox': [2.6804,
#           4.4639,
#           3.3314,
#           4.4345,
#           3.3303,
#           4.6302,
#           2.6793,
#           4.6312],
#          'confidence': 0.727}]},
#       {'text': 'UKBP Q',
#        'boundingBox': [3.4769,
#         4.3335,
#         4.527,
#         4.3102,
#         4.5303,
#         4.5702,
#         3.4769,
#         4.5869],
#        'words': [{'text': 'UKBP',
#          'boundingBox': [3.4863,
#           4.3417,
#           4.2654,
#           4.3243,
#           4.2649,
#           4.5821,
#           3.488,
#           4.5869],
#          'confidence': 0.694},
#         {'text': 'Q',
#          'boundingBox': [4.3141,
#           4.3217,
#           4.4762,
#           4.3132,
#           4.4751,
#           4.5784,
#           4.3134,
#           4.5813],
#          'confidence': 0.761}]},
#       {'text': 'Age (years): [3][ 6][ ]',
#        'boundingBox': [0.5434,
#         4.8902,
#         2.1568,
#         4.8636,
#         2.1601,
#         5.0702,
#         0.5434,
#         5.0769],
#        'words': [{'text': 'Age',
#          'boundingBox': [0.5438,
#           4.9164,
#           0.781,
#           4.9074,
#           0.7806,
#           5.0769,
#           0.5441,
#           5.0769],
#          'confidence': 0.958},
#         {'text': '(years):',
#          'boundingBox': [0.8127,
#           4.9063,
#           1.3188,
#           4.8887,
#           1.3167,
#           5.0769,
#           0.8121,
#           5.0769],
#          'confidence': 0.799},
#         {'text': '[3][',
#          'boundingBox': [1.361,
#           4.8873,
#           1.6985,
#           4.8768,
#           1.6951,
#           5.0764,
#           1.3587,
#           5.0769],
#          'confidence': 0.694},
#         {'text': '6][',
#          'boundingBox': [1.7302,
#           4.8759,
#           1.9938,
#           4.8684,
#           1.9895,
#           5.0755,
#           1.7267,
#           5.0763],
#          'confidence': 0.289},
#         {'text': ']',
#          'boundingBox': [2.0888,
#           4.8658,
#           2.1573,
#           4.8639,
#           2.1525,
#           5.0749,
#           2.0841,
#           5.0751],
#          'confidence': 0.694}]},
#       {'text': 'if <1 year old, [ ][ ] in months or if < 1 month, [ ][ ] in days',
#        'boundingBox': [2.8135,
#         4.8736,
#         6.9471,
#         4.8369,
#         6.9505,
#         5.0136,
#         2.8135,
#         5.0536],
#        'words': [{'text': 'if',
#          'boundingBox': [2.815,
#           4.8808,
#           2.9148,
#           4.8792,
#           2.9186,
#           5.0569,
#           2.819,
#           5.0569],
#          'confidence': 0.948},
#         {'text': '<1',
#          'boundingBox': [2.95,
#           4.8787,
#           3.1025,
#           4.8763,
#           3.106,
#           5.056,
#           2.9537,
#           5.0569],
#          'confidence': 0.914},
#         {'text': 'year',
#          'boundingBox': [3.1377,
#           4.8757,
#           3.3959,
#           4.8717,
#           3.3988,
#           5.0521,
#           3.1411,
#           5.0555],
#          'confidence': 0.958},
#         {'text': 'old,',
#          'boundingBox': [3.4311,
#           4.8712,
#           3.6541,
#           4.8681,
#           3.6565,
#           5.0489,
#           3.4339,
#           5.0517],
#          'confidence': 0.852},
#         {'text': '[',
#          'boundingBox': [3.6893,
#           4.8676,
#           3.8066,
#           4.866,
#           3.8087,
#           5.0471,
#           3.6916,
#           5.0485],
#          'confidence': 0.859},
#         {'text': '][',
#          'boundingBox': [3.9005,
#           4.8647,
#           4.0648,
#           4.8626,
#           4.0664,
#           5.044,
#           3.9024,
#           5.0459],
#          'confidence': 0.44},
#         {'text': ']',
#          'boundingBox': [4.1587,
#           4.8614,
#           4.2056,
#           4.8609,
#           4.2069,
#           5.0424,
#           4.1601,
#           5.043],
#          'confidence': 0.873},
#         {'text': 'in',
#          'boundingBox': [4.2408,
#           4.8604,
#           4.3582,
#           4.859,
#           4.3592,
#           5.0407,
#           4.2421,
#           5.042],
#          'confidence': 0.867},
#         {'text': 'months',
#          'boundingBox': [4.3934,
#           4.8586,
#           4.8746,
#           4.8534,
#           4.8746,
#           5.0353,
#           4.3944,
#           5.0403],
#          'confidence': 0.914},
#         {'text': 'or',
#          'boundingBox': [4.9098,
#           4.8531,
#           5.0271,
#           4.8519,
#           5.0268,
#           5.0337,
#           4.9097,
#           5.0349],
#          'confidence': 0.921},
#         {'text': 'if',
#          'boundingBox': [5.0623,
#           4.8515,
#           5.1679,
#           4.8505,
#           5.1674,
#           5.0323,
#           5.062,
#           5.0334],
#          'confidence': 0.945},
#         {'text': '<',
#          'boundingBox': [5.2032,
#           4.8502,
#           5.297,
#           4.8494,
#           5.2962,
#           5.0311,
#           5.2025,
#           5.032],
#          'confidence': 0.799},
#         {'text': '1',
#          'boundingBox': [5.3323,
#           4.8491,
#           5.3909,
#           4.8486,
#           5.3899,
#           5.0302,
#           5.3314,
#           5.0308],
#          'confidence': 0.857},
#         {'text': 'month,',
#          'boundingBox': [5.4261,
#           4.8483,
#           5.9073,
#           4.8446,
#           5.9053,
#           5.0257,
#           5.4251,
#           5.0299],
#          'confidence': 0.925},
#         {'text': '[',
#          'boundingBox': [5.9425,
#           4.8444,
#           6.0599,
#           4.8437,
#           6.0576,
#           5.0245,
#           5.9405,
#           5.0254],
#          'confidence': 0.82},
#         {'text': '][',
#          'boundingBox': [6.1538,
#           4.8431,
#           6.3181,
#           4.842,
#           6.3153,
#           5.0224,
#           6.1513,
#           5.0237],
#          'confidence': 0.57},
#         {'text': ']',
#          'boundingBox': [6.4002,
#           4.8416,
#           6.4472,
#           4.8414,
#           6.4441,
#           5.0214,
#           6.3973,
#           5.0218],
#          'confidence': 0.84},
#         {'text': 'in',
#          'boundingBox': [6.4824,
#           4.8412,
#           6.6115,
#           4.8407,
#           6.6081,
#           5.0203,
#           6.4793,
#           5.0212],
#          'confidence': 0.865},
#         {'text': 'days',
#          'boundingBox': [6.6467,
#           4.8405,
#           6.946,
#           4.8392,
#           6.942,
#           5.0179,
#           6.6433,
#           5.02],
#          'confidence': 0.954}]},
#       {'text': 'Sex at birth: a Male',
#        'boundingBox': [0.5334,
#         5.3336,
#         1.7968,
#         5.3136,
#         1.8001,
#         5.4836,
#         0.5367,
#         5.4969],
#        'words': [{'text': 'Sex',
#          'boundingBox': [0.5393,
#           5.3477,
#           0.7619,
#           5.3448,
#           0.7655,
#           5.4969,
#           0.5444,
#           5.4953],
#          'confidence': 0.958},
#         {'text': 'at',
#          'boundingBox': [0.7909,
#           5.3443,
#           0.9167,
#           5.3422,
#           0.9193,
#           5.4969,
#           0.7943,
#           5.4969],
#          'confidence': 0.958},
#         {'text': 'birth:',
#          'boundingBox': [0.9457,
#           5.3415,
#           1.3229,
#           5.3321,
#           1.323,
#           5.495,
#           0.9481,
#           5.4969],
#          'confidence': 0.937},
#         {'text': 'a',
#          'boundingBox': [1.3713,
#           5.3306,
#           1.4293,
#           5.3288,
#           1.4287,
#           5.4937,
#           1.371,
#           5.4944],
#          'confidence': 0.036},
#         {'text': 'Male',
#          'boundingBox': [1.4583,
#           5.3278,
#           1.7919,
#           5.3152,
#           1.7889,
#           5.4869,
#           1.4575,
#           5.4933],
#          'confidence': 0.957}]},
#       {'text': 'Female',
#        'boundingBox': [2.0168,
#         5.3236,
#         2.6535,
#         5.3136,
#         2.6568,
#         5.4736,
#         2.0201,
#         5.4803],
#        'words': [{'text': 'Female',
#          'boundingBox': [2.1906,
#           5.3298,
#           2.6525,
#           5.3149,
#           2.6598,
#           5.4796,
#           2.197,
#           5.4778],
#          'confidence': 0.694}]},
#       {'text': 'Place where the case was diagnosed: Country: UK',
#        'boundingBox': [0.54,
#         5.7469,
#         3.8869,
#         5.6869,
#         3.8903,
#         5.8836,
#         0.54,
#         5.9236],
#        'words': [{'text': 'Place',
#          'boundingBox': [0.5467,
#           5.7686,
#           0.8724,
#           5.7708,
#           0.8739,
#           5.9216,
#           0.5476,
#           5.9192],
#          'confidence': 0.959},
#         {'text': 'where',
#          'boundingBox': [0.902,
#           5.771,
#           1.287,
#           5.7708,
#           1.2892,
#           5.9228,
#           0.9036,
#           5.9218],
#          'confidence': 0.959},
#         {'text': 'the',
#          'boundingBox': [1.3166,
#           5.7707,
#           1.5239,
#           5.7696,
#           1.5265,
#           5.9228,
#           1.3189,
#           5.9228],
#          'confidence': 0.946},
#         {'text': 'case',
#          'boundingBox': [1.5535,
#           5.7692,
#           1.82,
#           5.7655,
#           1.8231,
#           5.921,
#           1.5562,
#           5.9226],
#          'confidence': 0.959},
#         {'text': 'was',
#          'boundingBox': [1.8497,
#           5.7651,
#           2.0964,
#           5.7605,
#           2.1,
#           5.9186,
#           1.8528,
#           5.9208],
#          'confidence': 0.958},
#         {'text': 'diagnosed:',
#          'boundingBox': [2.126,
#           5.7598,
#           2.8068,
#           5.7398,
#           2.8116,
#           5.9073,
#           2.1296,
#           5.9182],
#          'confidence': 0.948},
#         {'text': 'Country:',
#          'boundingBox': [2.8364,
#           5.7388,
#           3.4085,
#           5.7144,
#           3.4143,
#           5.8927,
#           2.8413,
#           5.9067],
#          'confidence': 0.916},
#         {'text': 'UK',
#          'boundingBox': [3.5563,
#           5.7063,
#           3.8027,
#           5.6929,
#           3.8092,
#           5.8798,
#           3.5624,
#           5.8879],
#          'confidence': 0.491}]},
#       {'text': 'Admin Level 1 (province): _WEST MIDLANDS',
#        'boundingBox': [0.7034,
#         5.9536,
#         4.3903,
#         5.867,
#         4.3936,
#         6.0936,
#         0.7067,
#         6.1336],
#        'words': [{'text': 'Admin',
#          'boundingBox': [0.709,
#           6.0091,
#           1.1071,
#           5.9888,
#           1.1122,
#           6.1336,
#           0.7147,
#           6.1313],
#          'confidence': 0.959},
#         {'text': 'Level',
#          'boundingBox': [1.1469,
#           5.9867,
#           1.4813,
#           5.9707,
#           1.4859,
#           6.1336,
#           1.152,
#           6.1336],
#          'confidence': 0.959},
#         {'text': '1',
#          'boundingBox': [1.5052,
#           5.9696,
#           1.5769,
#           5.9663,
#           1.5813,
#           6.1336,
#           1.5098,
#           6.1336],
#          'confidence': 0.893},
#         {'text': '(province):',
#          'boundingBox': [1.6008,
#           5.9651,
#           2.2778,
#           5.9357,
#           2.2811,
#           6.1336,
#           1.6052,
#           6.1336],
#          'confidence': 0.84},
#         {'text': '_WEST',
#          'boundingBox': [2.3017,
#           5.9348,
#           3.0346,
#           5.9078,
#           3.0368,
#           6.1276,
#           2.305,
#           6.1336],
#          'confidence': 0.417},
#         {'text': 'MIDLANDS',
#          'boundingBox': [3.194,
#           5.9024,
#           4.3495,
#           5.8698,
#           4.3496,
#           6.101,
#           3.1959,
#           6.1254],
#          'confidence': 0.219}]},
#       {'text': 'Case usual place of residency: Country: _UK',
#        'boundingBox': [0.5667,
#         6.3803,
#         3.4369,
#         6.307,
#         3.4402,
#         6.5203,
#         0.5667,
#         6.5637],
#        'words': [{'text': 'Case',
#          'boundingBox': [0.5676,
#           6.4103,
#           0.8446,
#           6.4098,
#           0.8454,
#           6.5637,
#           0.5687,
#           6.5637],
#          'confidence': 0.959},
#         {'text': 'usual',
#          'boundingBox': [0.8749,
#           6.4097,
#           1.2073,
#           6.4065,
#           1.2075,
#           6.5627,
#           0.8756,
#           6.5637],
#          'confidence': 0.959},
#         {'text': 'place',
#          'boundingBox': [1.2375,
#           6.4061,
#           1.57,
#           6.3998,
#           1.5696,
#           6.5602,
#           1.2377,
#           6.5626],
#          'confidence': 0.959},
#         {'text': 'of',
#          'boundingBox': [1.6002,
#           6.3991,
#           1.7311,
#           6.396,
#           1.7305,
#           6.5586,
#           1.5998,
#           6.5599],
#          'confidence': 0.958},
#         {'text': 'residency:',
#          'boundingBox': [1.7613,
#           6.3952,
#           2.4258,
#           6.37,
#           2.4242,
#           6.5484,
#           1.7607,
#           6.5583],
#          'confidence': 0.954},
#         {'text': 'Country:',
#          'boundingBox': [2.456,
#           6.3686,
#           2.959,
#           6.3417,
#           2.9566,
#           6.537,
#           2.4543,
#           6.5478],
#          'confidence': 0.945},
#         {'text': '_UK',
#          'boundingBox': [2.9892,
#           6.34,
#           3.3813,
#           6.3137,
#           3.3782,
#           6.5257,
#           2.9867,
#           6.5363],
#          'confidence': 0.303}]},
#       {'text': 'Section 2: Clinical Status',
#        'boundingBox': [0.5467,
#         6.8437,
#         2.3368,
#         6.8303,
#         2.3368,
#         6.977,
#         0.5467,
#         6.997],
#        'words': [{'text': 'Section',
#          'boundingBox': [0.5626,
#           6.8459,
#           1.0993,
#           6.8401,
#           1.1081,
#           6.9926,
#           0.5711,
#           7.0001],
#          'confidence': 0.959},
#         {'text': '2:',
#          'boundingBox': [1.1296,
#           6.8398,
#           1.2815,
#           6.8383,
#           1.2904,
#           6.9902,
#           1.1385,
#           6.9922],
#          'confidence': 0.941},
#         {'text': 'Clinical',
#          'boundingBox': [1.3119,
#           6.8381,
#           1.8385,
#           6.8339,
#           1.8477,
#           6.9831,
#           1.3208,
#           6.9897],
#          'confidence': 0.959},
#         {'text': 'Status',
#          'boundingBox': [1.8689,
#           6.8337,
#           2.3297,
#           6.8309,
#           2.3391,
#           6.9773,
#           1.8781,
#           6.9827],
#          'confidence': 0.959}]},
#       {'text': 'Date of first laboratory confirmation test:',
#        'boundingBox': [0.5334,
#         7.1337,
#         3.0702,
#         7.1037,
#         3.0702,
#         7.2637,
#         0.5367,
#         7.2837],
#        'words': [{'text': 'Date',
#          'boundingBox': [0.5586,
#           7.1428,
#           0.8662,
#           7.146,
#           0.8738,
#           7.2837,
#           0.5674,
#           7.2837],
#          'confidence': 0.929},
#         {'text': 'of',
#          'boundingBox': [0.8942,
#           7.1463,
#           1.0154,
#           7.1466,
#           1.0223,
#           7.2837,
#           0.9017,
#           7.2837],
#          'confidence': 0.958},
#         {'text': 'first',
#          'boundingBox': [1.0433,
#           7.1467,
#           1.2857,
#           7.147,
#           1.2916,
#           7.2837,
#           1.0502,
#           7.2837],
#          'confidence': 0.953},
#         {'text': 'laboratory',
#          'boundingBox': [1.3137,
#           7.1469,
#           1.9661,
#           7.1402,
#           1.9694,
#           7.2797,
#           1.3194,
#           7.2837],
#          'confidence': 0.943},
#         {'text': 'confirmation',
#          'boundingBox': [1.9941,
#           7.1397,
#           2.7768,
#           7.118,
#           2.7768,
#           7.2675,
#           1.9972,
#           7.2794],
#          'confidence': 0.951},
#         {'text': 'test:',
#          'boundingBox': [2.8048,
#           7.1169,
#           3.0702,
#           7.1066,
#           3.0691,
#           7.2614,
#           2.8046,
#           7.2669],
#          'confidence': 0.947}]},
#       {'text': 'LIJLZ/LOJ4 1/LZILOL ZILQI',
#        'boundingBox': [4.3703,
#         7.0637,
#         6.8505,
#         7.037,
#         6.8538,
#         7.2337,
#         4.3703,
#         7.267],
#        'words': [{'text': 'LIJLZ/LOJ4',
#          'boundingBox': [4.3807,
#           7.0642,
#           5.5653,
#           7.0594,
#           5.5625,
#           7.2558,
#           4.3781,
#           7.267],
#          'confidence': 0.412},
#         {'text': '1/LZILOL',
#          'boundingBox': [5.6186,
#           7.0589,
#           6.3772,
#           7.0481,
#           6.3742,
#           7.2414,
#           5.6157,
#           7.255],
#          'confidence': 0.272},
#         {'text': 'ZILQI',
#          'boundingBox': [6.4171,
#           7.0474,
#           6.8496,
#           7.0386,
#           6.8465,
#           7.2306,
#           6.4141,
#           7.2405],
#          'confidence': 0.252}]},
#       {'text': 'Any symptoms* or signs at time of specimen collection that resulted in first laboratory confirmation?',
#        'boundingBox': [0.5767,
#         7.5604,
#         7.1638,
#         7.4704,
#         7.1671,
#         7.6404,
#         0.5767,
#         7.7204],
#        'words': [{'text': 'Any',
#          'boundingBox': [0.5777,
#           7.5771,
#           0.828,
#           7.572,
#           0.8286,
#           7.7186,
#           0.5785,
#           7.7204],
#          'confidence': 0.958},
#         {'text': 'symptoms*',
#          'boundingBox': [0.8563,
#           7.5715,
#           1.612,
#           7.5563,
#           1.6119,
#           7.7099,
#           0.8569,
#           7.7183],
#          'confidence': 0.873},
#         {'text': 'or',
#          'boundingBox': [1.6404,
#           7.5557,
#           1.7915,
#           7.5529,
#           1.7912,
#           7.7078,
#           1.6402,
#           7.7096],
#          'confidence': 0.958},
#         {'text': 'signs',
#          'boundingBox': [1.8199,
#           7.5523,
#           2.1599,
#           7.5459,
#           2.1593,
#           7.7037,
#           1.8195,
#           7.7075],
#          'confidence': 0.958},
#         {'text': 'at',
#          'boundingBox': [2.1883,
#           7.5454,
#           2.33,
#           7.5427,
#           2.3291,
#           7.7017,
#           2.1876,
#           7.7033],
#          'confidence': 0.909},
#         {'text': 'time',
#          'boundingBox': [2.3583,
#           7.5422,
#           2.6701,
#           7.5366,
#           2.6689,
#           7.6979,
#           2.3575,
#           7.7014],
#          'confidence': 0.952},
#         {'text': 'of',
#          'boundingBox': [2.6984,
#           7.5361,
#           2.8401,
#           7.5337,
#           2.8388,
#           7.696,
#           2.6972,
#           7.6976],
#          'confidence': 0.958},
#         {'text': 'specimen',
#          'boundingBox': [2.8684,
#           7.5332,
#           3.4825,
#           7.5226,
#           3.4805,
#           7.6886,
#           2.8671,
#           7.6956],
#          'confidence': 0.953},
#         {'text': 'collection',
#          'boundingBox': [3.5108,
#           7.5221,
#           4.1438,
#           7.512,
#           4.1412,
#           7.6809,
#           3.5089,
#           7.6883],
#          'confidence': 0.958},
#         {'text': 'that',
#          'boundingBox': [4.1721,
#           7.5116,
#           4.4555,
#           7.5072,
#           4.4527,
#           7.6773,
#           4.1695,
#           7.6806],
#          'confidence': 0.958},
#         {'text': 'resulted',
#          'boundingBox': [4.4839,
#           7.5068,
#           5.0129,
#           7.4991,
#           5.0095,
#           7.6707,
#           4.481,
#           7.677],
#          'confidence': 0.928},
#         {'text': 'in',
#          'boundingBox': [5.0413,
#           7.4987,
#           5.1735,
#           7.4967,
#           5.17,
#           7.6688,
#           5.0378,
#           7.6704],
#          'confidence': 0.958},
#         {'text': 'first',
#          'boundingBox': [5.2019,
#           7.4963,
#           5.4853,
#           7.4925,
#           5.4814,
#           7.6651,
#           5.1983,
#           7.6685],
#          'confidence': 0.849},
#         {'text': 'laboratory',
#          'boundingBox': [5.5136,
#           7.4921,
#           6.2128,
#           7.4829,
#           6.2082,
#           7.6564,
#           5.5098,
#           7.6648],
#          'confidence': 0.954},
#         {'text': 'confirmation?',
#          'boundingBox': [6.2411,
#           7.4826,
#           7.1622,
#           7.4718,
#           7.1568,
#           7.6448,
#           6.2365,
#           7.656],
#          'confidence': 0.936}]},
#       {'text': 'No (i.e., asymptomatic)',
#        'boundingBox': [0.5534,
#         7.7737,
#         2.1201,
#         7.7604,
#         2.1235,
#         7.9171,
#         0.5567,
#         7.9371],
#        'words': [{'text': 'No',
#          'boundingBox': [0.6827,
#           7.7732,
#           0.8802,
#           7.7718,
#           0.8817,
#           7.9377,
#           0.6836,
#           7.9402],
#          'confidence': 0.737},
#         {'text': '(i.e.,',
#          'boundingBox': [0.9131,
#           7.7716,
#           1.1545,
#           7.7699,
#           1.1567,
#           7.9333,
#           0.9147,
#           7.9373],
#          'confidence': 0.837},
#         {'text': 'asymptomatic)',
#          'boundingBox': [1.1875,
#           7.7697,
#           2.1146,
#           7.7636,
#           2.1193,
#           7.909,
#           1.1897,
#           7.9328],
#          'confidence': 0.916}]},
#       {'text': 'DYes',
#        'boundingBox': [2.3568,
#         7.7537,
#         2.8369,
#         7.7437,
#         2.8435,
#         7.9037,
#         2.3568,
#         7.9104],
#        'words': [{'text': 'DYes',
#          'boundingBox': [2.4388,
#           7.7619,
#           2.8388,
#           7.7457,
#           2.8429,
#           7.9095,
#           2.4396,
#           7.9091],
#          'confidence': 0.487}]},
#       {'text': 'Unknown',
#        'boundingBox': [3.0635,
#         7.747,
#         3.8136,
#         7.7337,
#         3.8169,
#         7.8871,
#         3.0669,
#         7.9004],
#        'words': [{'text': 'Unknown',
#          'boundingBox': [3.2281,
#           7.7464,
#           3.8073,
#           7.7369,
#           3.8086,
#           7.8905,
#           3.2336,
#           7.8967],
#          'confidence': 0.91}]},
#       {'text': 'If yes, date of onset of symptoms:',
#        'boundingBox': [0.7467,
#         7.9804,
#         2.8469,
#         7.9671,
#         2.8502,
#         8.1237,
#         0.7467,
#         8.1404],
#        'words': [{'text': 'If',
#          'boundingBox': [0.7536,
#           7.9887,
#           0.8457,
#           7.9869,
#           0.8529,
#           8.143,
#           0.7611,
#           8.1437],
#          'confidence': 0.855},
#         {'text': 'yes,',
#          'boundingBox': [0.8764,
#           7.9864,
#           1.1014,
#           7.9822,
#           1.1079,
#           8.1387,
#           0.8835,
#           8.1424],
#          'confidence': 0.892},
#         {'text': 'date',
#          'boundingBox': [1.1321,
#           7.9818,
#           1.4185,
#           7.9774,
#           1.4242,
#           8.1345,
#           1.1385,
#           8.1383],
#          'confidence': 0.958},
#         {'text': 'of',
#          'boundingBox': [1.4492,
#           7.977,
#           1.5821,
#           7.9753,
#           1.5874,
#           8.1327,
#           1.4548,
#           8.1341],
#          'confidence': 0.958},
#         {'text': 'onset',
#          'boundingBox': [1.6128,
#           7.9749,
#           1.9606,
#           7.9715,
#           1.9648,
#           8.1297,
#           1.618,
#           8.1324],
#          'confidence': 0.954},
#         {'text': 'of',
#          'boundingBox': [1.9913,
#           7.9713,
#           2.1141,
#           7.9705,
#           2.1179,
#           8.129,
#           1.9954,
#           8.1295],
#          'confidence': 0.958},
#         {'text': 'symptoms:',
#          'boundingBox': [2.1448,
#           7.9703,
#           2.8455,
#           7.9684,
#           2.8473,
#           8.1287,
#           2.1485,
#           8.1288],
#          'confidence': 0.956}]},
#       {'text': 'LIJL 7/L OILCIVIL ZILOIL21101',
#        'boundingBox': [4.4036,
#         7.8571,
#         6.8771,
#         7.8204,
#         6.8805,
#         8.1037,
#         4.407,
#         8.1337],
#        'words': [{'text': 'LIJL',
#          'boundingBox': [4.4051,
#           7.8603,
#           4.7596,
#           7.8582,
#           4.7672,
#           8.1337,
#           4.414,
#           8.1337],
#          'confidence': 0.419},
#         {'text': '7/L',
#          'boundingBox': [4.8142,
#           7.8578,
#           5.1232,
#           7.855,
#           5.1294,
#           8.1337,
#           4.8215,
#           8.1337],
#          'confidence': 0.278},
#         {'text': 'OILCIVIL',
#          'boundingBox': [5.1778,
#           7.8543,
#           5.7777,
#           7.8462,
#           5.7814,
#           8.1267,
#           5.1838,
#           8.1337],
#          'confidence': 0.251},
#         {'text': 'ZILOIL21101',
#          'boundingBox': [5.8323,
#           7.8453,
#           6.8775,
#           7.823,
#           6.877,
#           8.1023,
#           5.8357,
#           8.1258],
#          'confidence': 0.416}]},
#       {'text': 'Underlying conditions and comorbidity:',
#        'boundingBox': [0.6,
#         8.4071,
#         3.2302,
#         8.3704,
#         3.2336,
#         8.5371,
#         0.6,
#         8.5738],
#        'words': [{'text': 'Underlying',
#          'boundingBox': [0.6005,
#           8.4111,
#           1.308,
#           8.4045,
#           1.3128,
#           8.5678,
#           0.6013,
#           8.5734],
#          'confidence': 0.959},
#         {'text': 'conditions',
#          'boundingBox': [1.3399,
#           8.4042,
#           2.0208,
#           8.3949,
#           2.0297,
#           8.5592,
#           1.3449,
#           8.5676],
#          'confidence': 0.917},
#         {'text': 'and',
#          'boundingBox': [2.0528,
#           8.3944,
#           2.3187,
#           8.39,
#           2.3293,
#           8.5547,
#           2.0618,
#           8.5588],
#          'confidence': 0.958},
#         {'text': 'comorbidity:',
#          'boundingBox': [2.3506,
#           8.3894,
#           3.2176,
#           8.372,
#           3.2333,
#           8.538,
#           2.3614,
#           8.5542],
#          'confidence': 0.925}]},
#       {'text': 'Any underlying conditions?',
#        'boundingBox': [0.59,
#         8.6304,
#         2.2335,
#         8.6038,
#         2.2368,
#         8.7604,
#         0.59,
#         8.7871],
#        'words': [{'text': 'Any',
#          'boundingBox': [0.5922,
#           8.632,
#           0.824,
#           8.6291,
#           0.8226,
#           8.7871,
#           0.5902,
#           8.7871],
#          'confidence': 0.958},
#         {'text': 'underlying',
#          'boundingBox': [0.8549,
#           8.6287,
#           1.5141,
#           8.6189,
#           1.5146,
#           8.7771,
#           0.8536,
#           8.7871],
#          'confidence': 0.958},
#         {'text': 'conditions?',
#          'boundingBox': [1.545,
#           8.6184,
#           2.2298,
#           8.6059,
#           2.2323,
#           8.7574,
#           1.5456,
#           8.7764],
#          'confidence': 0.958}]},
#       {'text': 'NO',
#        'boundingBox': [2.8502,
#         8.5938,
#         3.1835,
#         8.5804,
#         3.1869,
#         8.7338,
#         2.8535,
#         8.7404],
#        'words': [{'text': 'NO',
#          'boundingBox': [2.9766,
#           8.5866,
#           3.1759,
#           8.5806,
#           3.1805,
#           8.7339,
#           2.9812,
#           8.7399],
#          'confidence': 0.848}]},
#       {'text': 'Yes',
#        'boundingBox': [3.4502,
#         8.5971,
#         3.8769,
#         8.5738,
#         3.8836,
#         8.7138,
#         3.4569,
#         8.7371],
#        'words': [{'text': 'Yes',
#          'boundingBox': [3.6296,
#           8.5898,
#           3.8686,
#           8.5749,
#           3.877,
#           8.7176,
#           3.6374,
#           8.7315],
#          'confidence': 0.32}]},
#       {'text': 'Unknown',
#        'boundingBox': [4.0169,
#         8.5804,
#         4.8103,
#         8.5671,
#         4.8137,
#         8.7138,
#         4.0203,
#         8.7304],
#        'words': [{'text': 'Unknown',
#          'boundingBox': [4.1882,
#           8.5829,
#           4.7796,
#           8.5687,
#           4.7825,
#           8.7174,
#           4.1948,
#           8.7241],
#          'confidence': 0.727}]},
#       {'text': 'If yes, please check all that apply:',
#        'boundingBox': [0.72,
#         9.0371,
#         2.7435,
#         9.0171,
#         2.7435,
#         9.1971,
#         0.72,
#         9.2171],
#        'words': [{'text': 'If',
#          'boundingBox': [0.7203,
#           9.0466,
#           0.7709,
#           9.0466,
#           0.7743,
#           9.2162,
#           0.7236,
#           9.2171],
#          'confidence': 0.566},
#         {'text': 'yes,',
#          'boundingBox': [0.8046,
#           9.0466,
#           1.0293,
#           9.0466,
#           1.0333,
#           9.2084,
#           0.808,
#           9.2152],
#          'confidence': 0.874},
#         {'text': 'please',
#          'boundingBox': [1.063,
#           9.0464,
#           1.4675,
#           9.0438,
#           1.4724,
#           9.1996,
#           1.067,
#           9.2076],
#          'confidence': 0.956},
#         {'text': 'check',
#          'boundingBox': [1.5012,
#           9.0435,
#           1.8495,
#           9.0391,
#           1.8553,
#           9.1958,
#           1.5062,
#           9.1991],
#          'confidence': 0.959},
#         {'text': 'all',
#          'boundingBox': [1.8832,
#           9.0386,
#           2.0181,
#           9.0361,
#           2.0241,
#           9.1958,
#           1.889,
#           9.1957],
#          'confidence': 0.958},
#         {'text': 'that',
#          'boundingBox': [2.0518,
#           9.0354,
#           2.2989,
#           9.0302,
#           2.3056,
#           9.1971,
#           2.0579,
#           9.1958],
#          'confidence': 0.95},
#         {'text': 'apply:',
#          'boundingBox': [2.3326,
#           9.0294,
#           2.7314,
#           9.0188,
#           2.739,
#           9.2029,
#           2.3394,
#           9.1973],
#          'confidence': 0.94}]},
#       {'text': 'Pregnancy (trimester:',
#        'boundingBox': [0.6734,
#         9.2671,
#         2.0835,
#         9.2638,
#         2.0835,
#         9.4138,
#         0.6734,
#         9.4238],
#        'words': [{'text': 'Pregnancy',
#          'boundingBox': [0.7818,
#           9.27,
#           1.4214,
#           9.2717,
#           1.4257,
#           9.4224,
#           0.7888,
#           9.4265],
#          'confidence': 0.954},
#         {'text': '(trimester:',
#          'boundingBox': [1.4524,
#           9.2716,
#           2.0868,
#           9.2654,
#           2.0868,
#           9.4066,
#           1.4565,
#           9.422],
#          'confidence': 0.762}]},
#       {'text': 'Post-partum (< 6 weeks)',
#        'boundingBox': [4.397,
#         9.2071,
#         6.0371,
#         9.1838,
#         6.0404,
#         9.3538,
#         4.397,
#         9.3738],
#        'words': [{'text': 'Post-partum',
#          'boundingBox': [4.5198,
#           9.2106,
#           5.2628,
#           9.2029,
#           5.2652,
#           9.3707,
#           4.5209,
#           9.3738],
#          'confidence': 0.864},
#         {'text': '(<',
#          'boundingBox': [5.3158,
#           9.202,
#           5.4644,
#           9.1991,
#           5.4672,
#           9.3668,
#           5.3184,
#           9.37],
#          'confidence': 0.847},
#         {'text': '6',
#          'boundingBox': [5.4962,
#           9.1984,
#           5.5705,
#           9.1969,
#           5.5735,
#           9.3645,
#           5.4991,
#           9.3661],
#          'confidence': 0.871},
#         {'text': 'weeks)',
#          'boundingBox': [5.6024,
#           9.1961,
#           6.0321,
#           9.1846,
#           6.0359,
#           9.3492,
#           5.6054,
#           9.3635],
#          'confidence': 0.911}]},
#       {'text': 'Cardiovascular disease, including hypertension',
#        'boundingBox': [0.67,
#         9.4771,
#         3.6736,
#         9.4338,
#         3.6769,
#         9.5905,
#         0.6734,
#         9.6305],
#        'words': [{'text': 'Cardiovascular',
#          'boundingBox': [0.7945,
#           9.48,
#           1.6838,
#           9.4649,
#           1.6879,
#           9.6258,
#           0.7962,
#           9.6305],
#          'confidence': 0.849},
#         {'text': 'disease,',
#          'boundingBox': [1.7131,
#           9.4644,
#           2.192,
#           9.4569,
#           2.1975,
#           9.6189,
#           1.7173,
#           9.6255],
#          'confidence': 0.958},
#         {'text': 'including',
#          'boundingBox': [2.2213,
#           9.4564,
#           2.7979,
#           9.4479,
#           2.8051,
#           9.6073,
#           2.2269,
#           9.6185],
#          'confidence': 0.959},
#         {'text': 'hypertension',
#          'boundingBox': [2.8272,
#           9.4475,
#           3.6482,
#           9.4365,
#           3.6577,
#           9.584,
#           2.8345,
#           9.6066],
#          'confidence': 0.957}]},
#       {'text': 'Immunodeficiency, including HIV',
#        'boundingBox': [4.387,
#         9.4238,
#         6.5771,
#         9.3805,
#         6.5804,
#         9.5538,
#         4.3903,
#         9.5938],
#        'words': [{'text': 'Immunodeficiency,',
#          'boundingBox': [4.5131,
#           9.4286,
#           5.6655,
#           9.4087,
#           5.6673,
#           9.568,
#           4.5149,
#           9.5911],
#          'confidence': 0.69},
#         {'text': 'including',
#          'boundingBox': [5.6978,
#           9.4078,
#           6.2792,
#           9.391,
#           6.2811,
#           9.56,
#           5.6997,
#           9.5675],
#          'confidence': 0.958},
#         {'text': 'HIV',
#          'boundingBox': [6.3115,
#           9.3899,
#           6.5591,
#           9.3813,
#           6.561,
#           9.5573,
#           6.3134,
#           9.5597],
#          'confidence': 0.909}]},
#       {'text': 'Diabetes',
#        'boundingBox': [0.6667,
#         9.6938,
#         1.3334,
#         9.6971,
#         1.3334,
#         9.8405,
#         0.6667,
#         9.8371],
#        'words': [{'text': 'Diabetes',
#          'boundingBox': [0.7889,
#           9.6967,
#           1.3286,
#           9.7029,
#           1.3285,
#           9.841,
#           0.7927,
#           9.8421],
#          'confidence': 0.844}]},
#       {'text': 'Renal disease',
#        'boundingBox': [4.4003,
#         9.6338,
#         5.347,
#         9.6271,
#         5.3504,
#         9.7805,
#         4.4036,
#         9.7971],
#        'words': [{'text': 'Renal',
#          'boundingBox': [4.5179,
#           9.6338,
#           4.8673,
#           9.6286,
#           4.866,
#           9.7827,
#           4.518,
#           9.7973],
#          'confidence': 0.799},
#         {'text': 'disease',
#          'boundingBox': [4.9001,
#           9.6285,
#           5.3424,
#           9.633,
#           5.3392,
#           9.7737,
#           4.8986,
#           9.7817],
#          'confidence': 0.959}]},
#       {'text': 'Liver disease',
#        'boundingBox': [0.6734,
#         9.9072,
#         1.5568,
#         9.9038,
#         1.5601,
#         10.0572,
#         0.6734,
#         10.0672],
#        'words': [{'text': 'Liver',
#          'boundingBox': [0.7846,
#           9.9084,
#           1.091,
#           9.9087,
#           1.0943,
#           10.0664,
#           0.7895,
#           10.0672],
#          'confidence': 0.848},
#         {'text': 'disease',
#          'boundingBox': [1.1227,
#           9.9086,
#           1.5611,
#           9.9041,
#           1.562,
#           10.0565,
#           1.1258,
#           10.066],
#          'confidence': 0.958}]},
#       {'text': 'Chronic lung disease',
#        'boundingBox': [4.387,
#         9.8538,
#         5.8071,
#         9.8405,
#         5.8071,
#         9.9905,
#         4.387,
#         10.0038],
#        'words': [{'text': 'Chronic',
#          'boundingBox': [4.5311,
#           9.8547,
#           4.9974,
#           9.8484,
#           5.0046,
#           10.0029,
#           4.5385,
#           10.0071],
#          'confidence': 0.909},
#         {'text': 'lung',
#          'boundingBox': [5.0272,
#           9.8481,
#           5.315,
#           9.8453,
#           5.322,
#           9.9991,
#           5.0344,
#           10.0025],
#          'confidence': 0.929},
#         {'text': 'disease',
#          'boundingBox': [5.3447,
#           9.845,
#           5.7962,
#           9.8419,
#           5.803,
#           9.9921,
#           5.3517,
#           9.9987],
#          'confidence': 0.952}]},
#       {'text': 'Chronic neurological or neuromuscular disease',
#        'boundingBox': [0.6734,
#         10.1138,
#         3.6669,
#         10.0738,
#         3.6702,
#         10.2438,
#         0.6767,
#         10.2805],
#        'words': [{'text': 'Chronic',
#          'boundingBox': [0.7952,
#           10.1208,
#           1.2664,
#           10.1174,
#           1.2761,
#           10.2728,
#           0.8062,
#           10.2791],
#          'confidence': 0.57},
#         {'text': 'neurological',
#          'boundingBox': [1.2978,
#           10.1171,
#           2.0622,
#           10.1081,
#           2.0697,
#           10.2632,
#           1.3074,
#           10.2724],
#          'confidence': 0.956},
#         {'text': 'or',
#          'boundingBox': [2.0936,
#           10.1076,
#           2.2297,
#           10.1055,
#           2.2368,
#           10.2614,
#           2.1011,
#           10.2629],
#          'confidence': 0.958},
#         {'text': 'neuromuscular',
#          'boundingBox': [2.2611,
#           10.105,
#           3.1929,
#           10.0871,
#           3.1974,
#           10.252,
#           2.2681,
#           10.2611],
#          'confidence': 0.946},
#         {'text': 'disease',
#          'boundingBox': [3.2243,
#           10.0864,
#           3.6692,
#           10.0755,
#           3.6725,
#           10.2481,
#           3.2288,
#           10.2517],
#          'confidence': 0.959}]},
#       {'text': 'Malignancy',
#        'boundingBox': [4.4003,
#         10.0772,
#         5.247,
#         10.0738,
#         5.247,
#         10.2238,
#         4.4003,
#         10.2272],
#        'words': [{'text': 'Malignancy',
#          'boundingBox': [4.5245,
#           10.0796,
#           5.2431,
#           10.0783,
#           5.2481,
#           10.2218,
#           4.5313,
#           10.2277],
#          'confidence': 0.812}]},
#       {'text': 'Other(s), please specify:',
#        'boundingBox': [0.7,
#         10.3372,
#         2.3168,
#         10.3172,
#         2.3168,
#         10.4772,
#         0.7034,
#         10.5005],
#        'words': [{'text': 'Other(s),',
#          'boundingBox': [0.8368,
#           10.3384,
#           1.3551,
#           10.3353,
#           1.3618,
#           10.4881,
#           0.8446,
#           10.4996],
#          'confidence': 0.855},
#         {'text': 'please',
#          'boundingBox': [1.3875,
#           10.335,
#           1.7871,
#           10.3298,
#           1.7928,
#           10.4819,
#           1.3941,
#           10.4875],
#          'confidence': 0.958},
#         {'text': 'specify:',
#          'boundingBox': [1.8194,
#           10.3293,
#           2.3107,
#           10.3197,
#           2.3153,
#           10.4783,
#           1.8251,
#           10.4815],
#          'confidence': 0.946}]}]}],
#    'documentResults': [{'docType': 'prebuilt:receipt',
#      'pageRange': [1, 1],
#      'fields': {'ReceiptType': {'type': 'string',
#        'valueString': 'Itemized',
#        'confidence': 0.608},
#       'MerchantName': {'type': 'string',
#        'valueString': 'World Health',
#        'text': 'World Health',
#        'boundingBox': [1.509,
#         0.3776,
#         3.0378,
#         0.3759,
#         3.0381,
#         0.6491,
#         1.5093,
#         0.6509],
#        'page': 1,
#        'confidence': 0.509,
#        'elements': ['#/readResults/0/lines/0/words/0',
#         '#/readResults/0/lines/0/words/1']}}}]}}]

# %%
result = []
for item in json_decode:
    
   # my_dict={}
    my_dict1=item.get('analyzeResult').get('readResults')[0].get('lines')[0].get('text')
    my_dict2= item.get('analyzeResult').get('readResults')[0].get('lines')[0].get('words')[0].get('text')
    my_dict3= item.get('analyzeResult').get('readResults')[0].get('lines')[0].get('words')[1].get('text')
    x= [my_dict1,my_dict2, my_dict3]
    
    print(x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-e49abcf6ad56> in <module>
#       3
#       4    # my_dict={}
# ----> 5     my_dict1=item.get('lines')[0].get('text')
#       6     my_dict2= item.get('analyzeResult').get('readResults')[0].get('lines')[0].get('words')[0].get('text')
#       7     my_dict3= item.get('analyzeResult').get('readResults')[0].get('lines')[0].get('words')[1].get('text')
#
# TypeError: 'NoneType' object is not subscriptable
