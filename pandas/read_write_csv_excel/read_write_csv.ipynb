# %%
import pandas as pd
df=pd.read_csv("test1.csv", header=1)
df
# Out:
#            Period        Short_Desc         Temp
# 0           Today      Mostly Sunny  High: 40 °F
# 1         Tonight  IncreasingClouds   Low: 32 °F
# 2       Wednesday     Mostly Cloudy  High: 44 °F
# 3  WednesdayNight     Mostly Cloudy   Low: 34 °F
# 4        Thursday      Mostly Sunny  High: 42 °F
# 5   ThursdayNight     Partly Cloudy   Low: 32 °F
# 6          Friday      Partly Sunny  High: 43 °F
# 7     FridayNight     Partly Cloudy   Low: 30 °F
# 8        Saturday             Sunny  High: 37 °F

# %%
df=pd.read_csv("test1.csv",skiprows=1)
df
# Out:
#            Period        Short_Desc         Temp
# 0           Today      Mostly Sunny  High: 40 °F
# 1         Tonight  IncreasingClouds   Low: 32 °F
# 2       Wednesday     Mostly Cloudy  High: 44 °F
# 3  WednesdayNight     Mostly Cloudy   Low: 34 °F
# 4        Thursday      Mostly Sunny  High: 42 °F
# 5   ThursdayNight     Partly Cloudy   Low: 32 °F
# 6          Friday      Partly Sunny  High: 43 °F
# 7     FridayNight     Partly Cloudy   Low: 30 °F
# 8        Saturday             Sunny  High: 37 °F

# %%
df=pd.read_csv("test1.csv",header=None)
df
# Out:
#                  0                 1            2
# 0          jupyter               NaN          NaN
# 1           Period        Short_Desc         Temp
# 2            Today      Mostly Sunny  High: 40 °F
# 3          Tonight  IncreasingClouds   Low: 32 °F
# 4        Wednesday     Mostly Cloudy  High: 44 °F
# 5   WednesdayNight     Mostly Cloudy   Low: 34 °F
# 6         Thursday      Mostly Sunny  High: 42 °F
# 7    ThursdayNight     Partly Cloudy   Low: 32 °F
# 8           Friday      Partly Sunny  High: 43 °F
# 9      FridayNight     Partly Cloudy   Low: 30 °F
# 10        Saturday             Sunny  High: 37 °F

# %%
df=pd.read_csv("test1.csv",header=None,names=['period','short_desc','Temp'],skiprows=2)
df
# Out:
#            period        short_desc         Temp
# 0           Today      Mostly Sunny  High: 40 °F
# 1         Tonight  IncreasingClouds   Low: 32 °F
# 2       Wednesday     Mostly Cloudy  High: 44 °F
# 3  WednesdayNight     Mostly Cloudy   Low: 34 °F
# 4        Thursday      Mostly Sunny  High: 42 °F
# 5   ThursdayNight     Partly Cloudy   Low: 32 °F
# 6          Friday      Partly Sunny  High: 43 °F
# 7     FridayNight     Partly Cloudy   Low: 30 °F
# 8        Saturday             Sunny  High: 37 °F

# %%
df=pd.read_csv("test1.csv",nrows=2)
df
# Out:
#     Period        Short_Desc         Temp
# 0    Today      Mostly Sunny  High: 40 °F
# 1  Tonight  IncreasingClouds   Low: 32 °F

# %%
df=pd.read_csv("test2.csv",na_values=["not availabel","n.a."])
df
# Out:
#            Period        Short_Desc         Temp
# 0           Today      Mostly Sunny  High: 40 °F
# 1         Tonight  IncreasingClouds   Low: 32 °F
# 2       Wednesday     Mostly Cloudy  High: 44 °F
# 3  WednesdayNight     Mostly Cloudy   Low: 34 °F
# 4        Thursday      Mostly Sunny  High: 42 °F
# 5   ThursdayNight     Partly Cloudy   Low: 32 °F
# 6          Friday      Partly Sunny  High: 43 °F
# 7     FridayNight               NaN          NaN
# 8        Saturday             Sunny  High: 37 °F

# %%
df.to_csv('new.csv',index=False)

# %%
df.columns
# Out:
# Index(['Period', 'Short_Desc', 'Temp'], dtype='object')

# %%
df.to_csv('new.csv',columns=['Period','Short_Desc'],index=None)
